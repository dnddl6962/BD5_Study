# %% [markdown]
# ## 0. 개발 환경 구성

# %% [markdown]
# #### 1) pgadmin4 다운로드
#
# > https://www.enterprisedb.com/downloads/postgres-postgresql-downloads
#
# > https://losskatsu.github.io/it-infra/postgresql-win/#%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C

# %% [markdown]
# #### 1) 가상 환경 생성
#
# ```
# python -m venv lecture
#
# call lecture/Scripts/activate
# ```

# %%
# !python -m venv lecture

# %% [markdown]
# #### 2) 필요 패키지 설치
#
# ```
# pip install -r requirements.txt
# ```
#
# ---

# %%
# !pip install -r requirements.txt
# Out:
# Collecting psycopg2==2.9.9 (from -r requirements.txt (line 1))
#   Using cached psycopg2-2.9.9-cp311-cp311-macosx_11_0_arm64.whl
# Collecting pandas==2.1.1 (from -r requirements.txt (line 2))
#   Using cached pandas-2.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting numpy==1.26.1 (from -r requirements.txt (line 3))
#   Using cached numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (115 kB)
# Collecting ipykernel==6.25.2 (from -r requirements.txt (line 4))
#   Using cached ipykernel-6.25.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting SQLAlchemy==2.0.22 (from -r requirements.txt (line 5))
#   Using cached SQLAlchemy-2.0.22-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.4 kB)
# Collecting python-dotenv==1.0.0 (from -r requirements.txt (line 6))
#   Downloading python_dotenv-1.0.0-py3-none-any.whl.metadata (21 kB)
# Collecting pymysql==1.1.0 (from -r requirements.txt (line 7))
#   Using cached PyMySQL-1.1.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting pyarrow==14.0.0 (from -r requirements.txt (line 8))
#   Using cached pyarrow-14.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: click==8.1.7 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from pandas==2.1.1->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from pandas==2.1.1->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from pandas==2.1.1->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: appnope in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (1.5.9)
# Requirement already satisfied: packaging in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: psutil in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (5.9.8)
# Requirement already satisfied: pyzmq>=20 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipykernel==6.25.2->-r requirements.txt (line 4)) (5.14.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from SQLAlchemy==2.0.22->-r requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: decorator in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (2.17.2)
# Requirement already satisfied: stack-data in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.25.2->-r requirements.txt (line 4)) (4.1.0)
# Requirement already satisfied: six>=1.5 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.1.1->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/bearjang/miniforge3/envs/gpu/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.25.2->-r requirements.txt (line 4)) (0.2.2)
# Using cached pandas-2.1.1-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
# Using cached numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached ipykernel-6.25.2-py3-none-any.whl (154 kB)
# Using cached SQLAlchemy-2.0.22-cp311-cp311-macosx_11_0_arm64.whl (2.0 MB)
# Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Using cached PyMySQL-1.1.0-py3-none-any.whl (44 kB)
# Using cached pyarrow-14.0.0-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
# Installing collected packages: SQLAlchemy, python-dotenv, pymysql, psycopg2, numpy, pyarrow, pandas, ipykernel
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.3
#     Uninstalling pandas-2.1.3:
#       Successfully uninstalled pandas-2.1.3
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.26.0
#     Uninstalling ipykernel-6.26.0:
#       Successfully uninstalled ipykernel-6.26.0
# Successfully installed SQLAlchemy-2.0.22 ipykernel-6.25.2 numpy-1.26.1 pandas-2.1.1 psycopg2-2.9.9 pyarrow-14.0.0 pymysql-1.1.0 python-dotenv-1.0.0

# %% [markdown]
# ## 1. Python을 통한 DB Connection

# %% [markdown]
# ### 1-1 mysql 라이브러리(psycopg2)를 활용한 Connection

# %% [markdown]
# ##### 1) Connection

# %%
import psycopg2

# database connection 생성
db = psycopg2.connect(host='localhost', dbname='postgres', user='postgres', password='12341234', port=5432)

# 커서 생성 > 특정 SQL 문장을 처리한 결과를 담고 있는 영역을 가리키는 일종의 포인터 / 쿼리문에 의해서 반환되는 결과값들을 저장하는 메모리공간
cursor = db.cursor()

# %% [markdown]
# ##### 2) CRUD Execution

# %%
create_query = "CREATE TABLE lecture (id SERIAL PRIMARY KEY, name VARCHAR(32), year INT, gender VARCHAR(10), count INT);"

insert_query = "INSERT INTO lecture VALUES(1, 'Ann', 2023, 'M', 1100);"

update_query = """
            UPDATE lecture 
            SET id = 1,
                name = 'HYUNSOO',
                year = '1991',
                gender = 'M',
                count = '1000'
            WHERE id = 1;
            """
delete_query = "DELETE FROM lecture WHERE id = 2001;"

drop_table = 'DROP TABLE lecture'

# %% [markdown]
# #### Connection Pool
#
# - 일정량의 Connection 객체를 미리 만들어서 pool에 저장했다가, 클라이언트 요청이 오면 Connection 객체를 빌려주고 해당 객체의 임무가 완료되면 다시 Connection 객체를 반납 받아서 pool에 저장하는 프로그래밍 기법이다.
# - 따라서 자원을 사용하면 반드시 반환해줘야하는데 이를 위해 DB 연결시 파이썬 with 구문을 사용한다.
# - 너무 많은 DB 접근이 발생할 경우에는 커넥션은 한정되어 있기 때문에 쓸 수 있는 커넥션이 발납될 때까지 기다려야 한다. 너무 많은 커넥션을 생성할 시에는 커넥션 또한 객체이므로 많은 메모리를 차지하게 되고, 프로그램의 성능을 떨어뜨리는 원인이 된다.
# - 즉, 커넥션 풀을 크게 설정하면 메모리 소모가 큰 대신 많은 사용자가 대기 시간이 줄어 들고, 반대로 커넥션 풀을 작게 설정하면 그 만큼 대기 시간이 길어진다. 따라서 사용량에 따라 적정량의 커넥션 객체를 생성해 두어야 한다.

# %%
cursor.close()

# %% [markdown]
# ##### 3) Pandas를 활용한 Bulk Insert

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/national_names.csv')

# %%
df.iloc[1]
# Out:
# id           2
# name      Anna
# year      1880
# gender       F
# count     2604
# Name: 1, dtype: object

# %%
for i in range(len(df)):
    datas = tuple(df.iloc[i])
    print(datas)
    query = f"INSERT INTO lecture VALUES{datas};"
    cursor.execute(query)

db.commit()

# %%
cursor.execute("SELECT * FROM lecture limit 5")
cursor.fetchall() #select쿼리의 결과를 가져옴
# Out:
# [(1, 'Mary', 1880, 'F', 7065),
#  (2, 'Anna', 1880, 'F', 2604),
#  (3, 'Emma', 1880, 'F', 2003),
#  (4, 'Elizabeth', 1880, 'F', 1939),
#  (5, 'Minnie', 1880, 'F', 1746)]

# %% [markdown]
# ### 1-2. ORM 라이브러리(sqlalchemy)를 활용한 Connection
#
# #### ORM(Object Relational Mapping) 이란?
# - Python 객체와 관계형 DB의 data를 매핑해주는 것
# - 장점
#     - Query가 아닌 코드로 데이터를 조작할 수 있어 개발자가 프로그래밍에 더 집중할 수 있도록 도와준다.
#     - 재사용 및 유지보수의 편리성이 증가한다.
#     - DBMS에 대한 종속성이 줄어든다.
#
# - 단점
#   - 완벽한 ORM으로만 서비스를 구현하기 어렵다.
#   - 프로시저가 많은 시스템에선 ORM의 객체 지향적인 장점을 활용하기 어렵다.

# %% [markdown]
# ##### 1) Connection 및 Session

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker # 접속이 끝나더라도 계속해서 연결 상태를 유지시키기 위해 sessionmaker를 통해 세션을 생성

engine_name = 'postgresql'
user_id = 'postgres'
user_pw = '12341234'
host = 'localhost'
port = '5432'
db_name = 'postgres'

db = create_engine(f'{engine_name}://{user_id}:{user_pw}@{host}:{port}/{db_name}')

Session = sessionmaker(db)
session = Session()

# %% [markdown]
# ##### 2) 매핑 테이블 생성

# %%
from sqlalchemy import Column, INTEGER, VARCHAR
from sqlalchemy.orm import declarative_base

Base = declarative_base()

class lecture(Base):
    __tablename__ = 'lecture'
    
    id = Column('id', INTEGER, primary_key=True, autoincrement=True) # autoincrement : 자동으로 1씩 증가
    name = Column('name', VARCHAR(10), nullable=False)
    year = Column('year', INTEGER, nullable=False)
    gender = Column('gender', VARCHAR(10), nullable=False)
    count = Column('count', INTEGER, nullable=False)

# Create
Base.metadata.create_all(db) # lecture 클래스에 정의된 메타데이터를 바탕으로 실제 데이터베이스 테이블을 생성

# Drop
# Sample.__table__.drop(db)

# %% [markdown]
# ##### 3) ORM을 활용한 CRUD

# %%
# 1) SELECT ONE

res = session.query(lecture).first()

print(res.id, res.name, res.year, res.gender, res.count)
# Out:
# 1 Mary 1880 F 7065

# %%
# 1) SELECT ALL

res = session.query(lecture).all()

for i in res:
    print(i.id, i.name, i.year, i.gender, i.count)
# Out:
# 1 Mary 1880 F 7065
# 2 Anna 1880 F 2604
# 3 Emma 1880 F 2003
# 4 Elizabeth 1880 F 1939
# 5 Minnie 1880 F 1746
# 6 Margaret 1880 F 1578
# 7 Ida 1880 F 1472
# 8 Alice 1880 F 1414
# 9 Bertha 1880 F 1320
# 10 Sarah 1880 F 1288
# 11 Annie 1880 F 1258
# 12 Clara 1880 F 1226
# 13 Ella 1880 F 1156
# 14 Florence 1880 F 1063
# 15 Cora 1880 F 1045
# 16 Martha 1880 F 1040
# 17 Laura 1880 F 1012
# 18 Nellie 1880 F 995
# 19 Grace 1880 F 982
# 20 Carrie 1880 F 949
# 21 Maude 1880 F 858
# 22 Mabel 1880 F 808
# 23 Bessie 1880 F 796
# 24 Jennie 1880 F 793
# 25 Gertrude 1880 F 787
# 26 Julia 1880 F 783
# 27 Hattie 1880 F 769
# 28 Edith 1880 F 768
# 29 Mattie 1880 F 704
# 30 Rose 1880 F 700
# 31 Catherine 1880 F 688
# 32 Lillian 1880 F 672
# 33 Ada 1880 F 652
# 34 Lillie 1880 F 647
# 35 Helen 1880 F 636
# 36 Jessie 1880 F 635
# 37 Louise 1880 F 635
# 38 Ethel 1880 F 633
# 39 Lula 1880 F 621
# 40 Myrtle 1880 F 615
# 41 Eva 1880 F 614
# 42 Frances 1880 F 605
# 43 Lena 1880 F 603
# 44 Lucy 1880 F 590
# 45 Edna 1880 F 588
# 46 Maggie 1880 F 582
# 47 Pearl 1880 F 569
# 48 Daisy 1880 F 564
# 49 Fannie 1880 F 560
# 50 Josephine 1880 F 544
# 51 Dora 1880 F 524
# 52 Rosa 1880 F 507
# 53 Katherine 1880 F 502
# 54 Agnes 1880 F 473
# 55 Marie 1880 F 471
# 56 Nora 1880 F 471
# 57 May 1880 F 462
# 58 Mamie 1880 F 436
# 59 Blanche 1880 F 427
# 60 Stella 1880 F 414
# 61 Ellen 1880 F 411
# 62 Nancy 1880 F 411
# 63 Effie 1880 F 406
# 64 Sallie 1880 F 404
# 65 Nettie 1880 F 403
# 66 Della 1880 F 391
# 67 Lizzie 1880 F 388
# 68 Flora 1880 F 365
# 69 Susie 1880 F 361
# 70 Maud 1880 F 345
# 71 Mae 1880 F 344
# 72 Etta 1880 F 323
# 73 Harriet 1880 F 319
# 74 Sadie 1880 F 317
# 75 Caroline 1880 F 306
# 76 Katie 1880 F 303
# 77 Lydia 1880 F 302
# 78 Elsie 1880 F 301
# 79 Kate 1880 F 299
# 80 Susan 1880 F 286
# 81 Mollie 1880 F 283
# 82 Alma 1880 F 277
# 83 Addie 1880 F 274
# 84 Georgia 1880 F 259
# 85 Eliza 1880 F 252
# 86 Lulu 1880 F 249
# 87 Nannie 1880 F 248
# 88 Lottie 1880 F 245
# 89 Amanda 1880 F 241
# 90 Belle 1880 F 238
# 91 Charlotte 1880 F 237
# 92 Rebecca 1880 F 236
# 93 Ruth 1880 F 234
# 94 Viola 1880 F 229
# 95 Olive 1880 F 224
# 96 Amelia 1880 F 221
# 97 Hannah 1880 F 221
# 98 Jane 1880 F 215
# 99 Virginia 1880 F 213
# 100 Emily 1880 F 210
# 101 Matilda 1880 F 210
# 102 Irene 1880 F 204
# 103 Kathryn 1880 F 204
# 104 Esther 1880 F 198
# 105 Willie 1880 F 192
# 106 Henrietta 1880 F 191
# 107 Ollie 1880 F 183
# 108 Amy 1880 F 167
# 109 Rachel 1880 F 166
# 110 Sara 1880 F 165
# 111 Estella 1880 F 162
# 112 Theresa 1880 F 153
# 113 Augusta 1880 F 151
# 114 Ora 1880 F 149
# 115 Pauline 1880 F 144
# 116 Josie 1880 F 141
# 117 Lola 1880 F 138
# 118 Sophia 1880 F 138
# 119 Leona 1880 F 137
# 120 Anne 1880 F 136
# 121 Mildred 1880 F 132
# 122 Ann 1880 F 131
# 123 Beulah 1880 F 131
# 124 Callie 1880 F 131
# 125 Lou 1880 F 131
# 126 Delia 1880 F 129
# 127 Eleanor 1880 F 129
# 128 Barbara 1880 F 127
# 129 Iva 1880 F 127
# 130 Louisa 1880 F 126
# 131 Maria 1880 F 125
# 132 Mayme 1880 F 124
# 133 Evelyn 1880 F 122
# 134 Estelle 1880 F 119
# 135 Nina 1880 F 119
# 136 Betty 1880 F 117
# 137 Marion 1880 F 115
# 138 Bettie 1880 F 113
# 139 Dorothy 1880 F 112
# 140 Luella 1880 F 111
# 141 Inez 1880 F 106
# 142 Lela 1880 F 106
# 143 Rosie 1880 F 106
# 144 Allie 1880 F 105
# 145 Millie 1880 F 105
# 146 Janie 1880 F 96
# 147 Cornelia 1880 F 94
# 148 Victoria 1880 F 93
# 149 Ruby 1880 F 92
# 150 Winifred 1880 F 92
# 151 Alta 1880 F 91
# 152 Celia 1880 F 90
# 153 Christine 1880 F 89
# 154 Beatrice 1880 F 87
# 155 Birdie 1880 F 85
# 156 Harriett 1880 F 83
# 157 Mable 1880 F 83
# 158 Myra 1880 F 83
# 159 Sophie 1880 F 83
# 160 Tillie 1880 F 83
# 161 Isabel 1880 F 81
# 162 Sylvia 1880 F 81
# 163 Carolyn 1880 F 80
# 164 Isabelle 1880 F 80
# 165 Leila 1880 F 80
# 166 Sally 1880 F 80
# 167 Ina 1880 F 79
# 168 Essie 1880 F 78
# 169 Bertie 1880 F 77
# 170 Nell 1880 F 77
# 171 Alberta 1880 F 76
# 172 Katharine 1880 F 76
# 173 Lora 1880 F 74
# 174 Rena 1880 F 74
# 175 Mina 1880 F 73
# 176 Rhoda 1880 F 73
# 177 Mathilda 1880 F 72
# 178 Abbie 1880 F 71
# 179 Eula 1880 F 70
# 180 Dollie 1880 F 69
# 181 Hettie 1880 F 69
# 182 Eunice 1880 F 67
# 183 Fanny 1880 F 67
# 184 Ola 1880 F 67
# 185 Lenora 1880 F 66
# 186 Adelaide 1880 F 65
# 187 Christina 1880 F 65
# 188 Lelia 1880 F 65
# 189 Nelle 1880 F 65
# 190 Sue 1880 F 65
# 191 Johanna 1880 F 64
# 192 Lilly 1880 F 64
# 193 Lucinda 1880 F 63
# 194 Minerva 1880 F 63
# 195 Lettie 1880 F 62
# 196 Roxie 1880 F 62
# 197 Cynthia 1880 F 61
# 198 Helena 1880 F 60
# 199 Hilda 1880 F 60
# 200 Hulda 1880 F 60
# 201 Bernice 1880 F 59
# 202 Genevieve 1880 F 59
# 203 Jean 1880 F 59
# 204 Cordelia 1880 F 58
# 205 Marian 1880 F 56
# 206 Francis 1880 F 55
# 207 Jeanette 1880 F 55
# 208 Adeline 1880 F 54
# 209 Gussie 1880 F 54
# 210 Leah 1880 F 54
# 211 Lois 1880 F 53
# 212 Lura 1880 F 53
# 213 Mittie 1880 F 53
# 214 Hallie 1880 F 51
# 215 Isabella 1880 F 50
# 216 Olga 1880 F 50
# 217 Phoebe 1880 F 50
# 218 Teresa 1880 F 50
# 219 Hester 1880 F 49
# 220 Lida 1880 F 49
# 221 Lina 1880 F 49
# 222 Winnie 1880 F 49
# 223 Claudia 1880 F 48
# 224 Marguerite 1880 F 48
# 225 Vera 1880 F 48
# 226 Cecelia 1880 F 47
# 227 Bess 1880 F 46
# 228 Emilie 1880 F 46
# 229 John 1880 F 46
# 230 Rosetta 1880 F 46
# 231 Verna 1880 F 46
# 232 Myrtie 1880 F 45
# 233 Cecilia 1880 F 44
# 234 Elva 1880 F 44
# 235 Olivia 1880 F 44
# 236 Ophelia 1880 F 44
# 237 Georgie 1880 F 43
# 238 Elnora 1880 F 42
# 239 Violet 1880 F 42
# 240 Adele 1880 F 41
# 241 Lily 1880 F 41
# 242 Linnie 1880 F 41
# 243 Loretta 1880 F 41
# 244 Madge 1880 F 41
# 245 Polly 1880 F 41
# 246 Virgie 1880 F 41
# 247 Eugenia 1880 F 40
# 248 Lucile 1880 F 40
# 249 Lucille 1880 F 40
# 250 Mabelle 1880 F 39
# 251 Rosalie 1880 F 39
# 252 Kittie 1880 F 38
# 253 Meta 1880 F 37
# 254 Angie 1880 F 36
# 255 Dessie 1880 F 36
# 256 Georgiana 1880 F 36
# 257 Lila 1880 F 36
# 258 Regina 1880 F 36
# 259 Selma 1880 F 36
# 260 Wilhelmina 1880 F 36
# 261 Bridget 1880 F 35
# 262 Lilla 1880 F 35
# 263 Malinda 1880 F 35
# 264 Vina 1880 F 35
# 265 Freda 1880 F 34
# 266 Gertie 1880 F 34
# 267 Jeannette 1880 F 34
# 268 Louella 1880 F 34
# 269 Mandy 1880 F 34
# 270 Roberta 1880 F 34
# 271 Cassie 1880 F 33
# 272 Corinne 1880 F 33
# 273 Ivy 1880 F 33
# 274 Melissa 1880 F 33
# 275 Lyda 1880 F 32
# 276 Naomi 1880 F 32
# 277 Norma 1880 F 32
# 278 Bell 1880 F 31
# 279 Margie 1880 F 31
# 280 Nona 1880 F 31
# 281 Zella 1880 F 31
# 282 Dovie 1880 F 30
# 283 Elvira 1880 F 30
# 284 Erma 1880 F 30
# 285 Irma 1880 F 30
# 286 Leota 1880 F 30
# 287 William 1880 F 30
# 288 Artie 1880 F 29
# 289 Blanch 1880 F 29
# 290 Charity 1880 F 29
# 291 Lorena 1880 F 29
# 292 Lucretia 1880 F 29
# 293 Orpha 1880 F 29
# 294 Alvina 1880 F 28
# 295 Annette 1880 F 28
# 296 Catharine 1880 F 28
# 297 Elma 1880 F 28
# 298 Geneva 1880 F 28
# 299 Janet 1880 F 28
# 300 Lee 1880 F 28
# 301 Leora 1880 F 28
# 302 Lona 1880 F 28
# 303 Miriam 1880 F 28
# 304 Zora 1880 F 28
# 305 Linda 1880 F 27
# 306 Octavia 1880 F 27
# 307 Sudie 1880 F 27
# 308 Zula 1880 F 27
# 309 Adella 1880 F 26
# 310 Alpha 1880 F 26
# 311 Frieda 1880 F 26
# 312 George 1880 F 26
# 313 Joanna 1880 F 26
# 314 Leonora 1880 F 26
# 315 Priscilla 1880 F 26
# 316 Tennie 1880 F 26
# 317 Angeline 1880 F 25
# 318 Docia 1880 F 25
# 319 Ettie 1880 F 25
# 320 Flossie 1880 F 25
# 321 Hanna 1880 F 25
# 322 Letha 1880 F 25
# 323 Minta 1880 F 25
# 324 Retta 1880 F 25
# 325 Rosella 1880 F 25
# 326 Adah 1880 F 24
# 327 Berta 1880 F 24
# 328 Elisabeth 1880 F 24
# 329 Elise 1880 F 24
# 330 Goldie 1880 F 24
# 331 Leola 1880 F 24
# 332 Margret 1880 F 24
# 333 Adaline 1880 F 23
# 334 Floy 1880 F 23
# 335 Idella 1880 F 23
# 336 Juanita 1880 F 23
# 337 Lenna 1880 F 23
# 338 Lucie 1880 F 23
# 339 Missouri 1880 F 23
# 340 Nola 1880 F 23
# 341 Zoe 1880 F 23
# 342 Eda 1880 F 22
# 1947 Loran 1880 M 5
# 1948 Lorin 1880 M 5
# 1949 Mace 1880 M 5
# 1950 Malcom 1880 M 5
# 1951 Manly 1880 M 5
# 1952 Manson 1880 M 5
# 1953 Matthias 1880 M 5
# 1954 Mattie 1880 M 5
# 1955 Merida 1880 M 5
# 1956 Miner 1880 M 5
# 1957 Montgomery 1880 M 5
# 1958 Moroni 1880 M 5
# 1959 Murdock 1880 M 5
# 1960 Myrtle 1880 M 5
# 1961 Nate 1880 M 5
# 1962 Nathanial 1880 M 5
# 1963 Nimrod 1880 M 5
# 1964 Nora 1880 M 5
# 1965 Norval 1880 M 5
# 1966 Nova 1880 M 5
# 1967 Orion 1880 M 5
# 1968 Orla 1880 M 5
# 1969 Orrie 1880 M 5
# 1970 Payton 1880 M 5
# 1971 Philo 1880 M 5
# 1972 Phineas 1880 M 5
# 1973 Presley 1880 M 5
# 1974 Ransom 1880 M 5
# 1975 Reece 1880 M 5
# 1976 Rene 1880 M 5
# 1977 Roswell 1880 M 5
# 1978 Rowland 1880 M 5
# 1979 Sampson 1880 M 5
# 1980 Samual 1880 M 5
# 1981 Santos 1880 M 5
# 1982 Schuyler 1880 M 5
# 1983 Sheppard 1880 M 5
# 1984 Spurgeon 1880 M 5
# 1985 Starling 1880 M 5
# 1986 Sylvanus 1880 M 5
# 1987 Theadore 1880 M 5
# 1988 Theophile 1880 M 5
# 1989 Tilmon 1880 M 5
# 1990 Tommy 1880 M 5
# 1991 Unknown 1880 M 5
# 1992 Vann 1880 M 5
# 1993 Wes 1880 M 5
# 1994 Winston 1880 M 5
# 1995 Wood 1880 M 5
# 1996 Woodie 1880 M 5
# 1997 Worthy 1880 M 5
# 1998 Wright 1880 M 5
# 1999 York 1880 M 5
# 2000 Zachariah 1880 M 5
# 2002 jiyun 2000 F 1234
# 2001 ung 1996 M 1234

# %%
# 2) INSERT

data1 = lecture(id=2002, name='jiyun', year=2000, gender='F', count=1234)
session.add(data1)
session.commit()

# %%
# 3) UPDATE

session.query(lecture).filter(lecture.name == 'ung').update({'gender':'M', 'count':1234})
session.commit()

# %%
# 4) DELETE

session.query(lecture).filter(lecture.id == 2).delete()
session.commit()

# %% [markdown]
# ## 2. dotenv 라이브러리를 활용한 민감 정보 관리
#
# - 환경 변수에 대한 관리를 효과적이고 안전하게 할 수 있도록 도와주는 python 라이브러리
# - DB정보, 비밀번호, API KEY 등 외부에 공유되거나 Git에 올라가면 안되는 값들을 하드코딩 하지 않고 사용이 가능.
#
#     ```
#     pip install python-dotenv
#     ```
#
#     > https://velog.io/@newnew_daddy/python-dotenv

# %% [markdown]
# ##### 1) 기본 기능 사용

# %%
import dotenv

# .env 경로 찾기
env_path = dotenv.find_dotenv()
print(env_path)

# .env 파일 load
dotenv.load_dotenv(env_path)

# .env 파일 변수값 출력
dotenv.dotenv_values(env_path)

# .env 파일 변수값 변경
# dotenv.set_key(env_path, '변경할 KEY', '변경할 VALUE')
# Out:
# /Users/bearjang/Downloads/DataEngineering/day1/.env
# OrderedDict([('POSTGRES_ENGINE', 'postgresql'),
#              ('POSTGRES_HOST', 'localhost'),
#              ('POSTGRES_DB_1', 'postgres'),
#              ('POSTGRES_USER', 'postgres'),
#              ('POSTGRES_PASSWORD', '12341234'),
#              ('POSTGRES_PORT', '5432')])

# %% [markdown]
# ##### 2) .env 파일 작성

# %%
POSTGRES_ENGINE = 'postgresql'
POSTGRES_HOST ='localhost'
POSTGRES_DB_1 = 'postgres'
POSTGRES_USER ='postgres'
POSTGRES_PASSWORD = '12341234'
POSTGRES_PORT = '5432'

# %% [markdown]
# ##### 3) 값들 Load해오기

# %%
import os

engine = os.environ.get('POSTGRES_ENGINE')
host = os.environ.get('POSTGRES_HOST')
dbname = os.environ.get('POSTGRES_DB_1')
user = os.environ.get('POSTGRES_USER')
password = os.environ.get('POSTGRES_PASSWORD')
port = os.environ.get('POSTGRES_PORT')

# %%
import psycopg2

# database connection 생성
db = psycopg2.connect(host=host, dbname=dbname, user=user, password=password, port=port)

# 커서 생성 > 특정 SQL 문장을 처리한 결과를 담고 있는 영역을 가리키는 일종의 포인터 / 쿼리문에 의해서 반환되는 결과값들을 저장하는 메모리공간
cursor = db.cursor()

# %% [markdown]
# ## 3. Python Class를 사용한 DB 접속 관리

# %% [markdown]
# ##### 1) Class 작성

# %%
class DBconnector:

    def __init__(self, host, dbname, user, password, port):
        self.host = host
        self.dbname = dbname
        self.user = user
        self.password = password
        self.port = port
        self.connect = self.postgres_connect()

    
    def __enter__(self):
        self.connect
        print('접속')
        return self


    def __exit__(self, exc_type, exc_value, traceback):
        self.conn.close()
        print('종료')

    def postgres_connect(self):
        self.conn = psycopg2.connect(host = self.host,
                        dbname = self.dbname,
                        user = self.user,
                        password = self.password,
                        port = self.port)
        
        return self

# %%
(host, dbname, user, password, port)
# Out:
# ('localhost', 'postgres', 'postgres', '12341234', '5432')

# %%
db_object = DBconnector(host, dbname, user, password, port)
db_conn = db_object.postgres_connect().conn

cursor = db_conn.cursor()

# %%
db_object = DBconnector(host, dbname, user, password, port)
# db_conn = db_object.postgres_connect().conn

with db_object as connected:
    db_conn = connected.conn
    cursor = db_conn.cursor()
    
    cursor.execute("SELECT * FROM lecture LIMIT 5")
    print(cursor.fetchall())
# Out:
# 접속
# [(1, 'Mary', 1880, 'F', 7065), (2, 'Anna', 1880, 'F', 2604), (3, 'Emma', 1880, 'F', 2003), (4, 'Elizabeth', 1880, 'F', 1939), (5, 'Minnie', 1880, 'F', 1746)]
# 종료

# %% [markdown]
# ##### 3) connection parameter 합치기

# %%
class DBconnector:

    def __init__(self, host, dbname, user, password, port):

        self.conn_params = dict(
            host = host,
            dbname = dbname,
            user = user,
            password = password,
            port = port
        )
            
        # self.host = host
        # self.dbname = db_name
        # self.user = user
        # self.password = password
        # self.port = port
        self.connect = self.postgres_connect()

    
    def __enter__(self):
        self.connect
        print('접속')
        return self


    def __exit__(self, exc_type, exc_value, traceback):
        self.conn.close()
        print('종료')

    def postgres_connect(self):
        self.conn = psycopg2.connect(**self.conn_params)
        
        return self
