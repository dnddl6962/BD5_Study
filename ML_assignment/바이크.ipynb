# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/3일차_회귀/datasets/
# Out:
# /content/drive/MyDrive/3일차_회귀/datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 데이터 불러오기 : 자전거 대여량 수요 예측

# %%
df = pd.read_csv('./bike_train.csv')
pd.set_option('display.max_columns', len(df.columns))
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# 주요 컬럼 설명
# - datetime: hourly date + timestamp
# - season: 1 = 봄, 2 = 여름, 3 = 가을, 4 = 겨울
# - holiday: 1 = 토, 일요일의 주말을 제외한 국경일 등의 휴일, 0 = 휴일이 아닌 날
# - workingday: 1 = 토, 일요일의 주말 및 휴일이 아닌 주중, 0 = 주말 및 휴일
# - weather: 1 = 맑음, 약간 구름 낀 흐림 2 = 안개, 안개 + 흐림 3 = 가벼운 눈, 가벼운 비 + 천둥 4 = 심한 눈/비, 천둥/번개
# - temp: 온도(섭씨)
# - atemp: 체감온도(섭씨)
# - humidity: 상대습도
# - windspeed: 풍속
# - casual: 사전에 등록되지 않는 사용자가 대여한 횟수
# - registered: 사전에 등록된 사용자가 대여한 횟수
# - count: 대여 횟수

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %% [markdown]
# 자전거 대여 횟수(Y) 예측을 위해 X를 만들어 모델에 적용해보세요!

# %%
# TODO : 데이터 전처리 자유롭게

# %%
df['year'] = df.datetime.apply(lambda x: x.year)
df['month'] = df.datetime.apply(lambda x : x.month)
df['day'] = df.datetime.apply(lambda x : x.day)
df['hour'] = df.datetime.apply(lambda x: x.hour)

# %%
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  ...  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84  ...
# 1     2011-01-01 01:00:00       1        0           0        1   9.02  ...
# 2     2011-01-01 02:00:00       1        0           0        1   9.02  ...
# 3     2011-01-01 03:00:00       1        0           0        1   9.84  ...
# 4     2011-01-01 04:00:00       1        0           0        1   9.84  ...
# ...                   ...     ...      ...         ...      ...    ...  ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58  ...
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76  ...
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94  ...
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94  ...
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12  ...
#
#        registered  count  year  month  day  hour
# 0              13     16  2011      1    1     0
# 1              32     40  2011      1    1     1
# 2              27     32  2011      1    1     2
# 3              10     13  2011      1    1     3
# 4               1      1  2011      1    1     4
# ...           ...    ...   ...    ...  ...   ...
# 10881         329    336  2012     12   19    19
# 10882         231    241  2012     12   19    20
# 10883         164    168  2012     12   19    21
# 10884         117    129  2012     12   19    22
# 10885          84     88  2012     12   19    23
#
# [10886 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'year', 'month', 'day', 'hour'],
#       dtype='object')

# %%
del df['datetime']

# %%
del df['casual']

# %%
del df['registered']

# %%
df
# Out:
#        season  holiday  workingday  weather   temp   atemp  ...  windspeed  \
# 0           1        0           0        1   9.84  14.395  ...     0.0000
# 1           1        0           0        1   9.02  13.635  ...     0.0000
# 2           1        0           0        1   9.02  13.635  ...     0.0000
# 3           1        0           0        1   9.84  14.395  ...     0.0000
# 4           1        0           0        1   9.84  14.395  ...     0.0000
# ...       ...      ...         ...      ...    ...     ...  ...        ...
# 10881       4        0           1        1  15.58  19.695  ...    26.0027
# 10882       4        0           1        1  14.76  17.425  ...    15.0013
# 10883       4        0           1        1  13.94  15.910  ...    15.0013
# 10884       4        0           1        1  13.94  17.425  ...     6.0032
# 10885       4        0           1        1  13.12  16.665  ...     8.9981
#
#        count  year  month  day  hour
# 0         16  2011      1    1     0
# 1         40  2011      1    1     1
# 2         32  2011      1    1     2
# 3         13  2011      1    1     3
# 4          1  2011      1    1     4
# ...      ...   ...    ...  ...   ...
# 10881    336  2012     12   19    19
# 10882    241  2012     12   19    20
# 10883    168  2012     12   19    21
# 10884    129  2012     12   19    22
# 10885     88  2012     12   19    23
#
# [10886 rows x 13 columns]

# %%
X = df[['season',
       'holiday',
       'workingday',
       'weather',
       'temp',
        'atemp',
        'humidity',
        'windspeed',
        'year', 'month', 'day', 'hour']]
y = df['count']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_features_ohe = pd.get_dummies(X, columns=['year', 'month','day', 'hour', 'holiday',
                                              'workingday','season','weather'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features_ohe, y,
                                                    test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %% [markdown]
# ### 모델 적용 / 평가

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 사이킷런의 mean_square_error() 를 이용하여 RMSE 계산
def rmse(y,pred):
    return np.sqrt(mean_squared_error(y,pred))

# MSE, RMSE, RMSLE 를 모두 계산
def evaluate_regr(y,pred):
    rmse_val = rmse(y,pred)
    # MAE 는 scikit learn의 mean_absolute_error() 로 계산
    mae_val = mean_absolute_error(y,pred)
    print('RMSE: {0:.3F}, MAE: {1:.3F}'.format(rmse_val, mae_val))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


lr_reg = LinearRegression()

# %%
lr_reg.fit(X_train_poly, y_train)
pred = lr_reg.predict(X_test_poly)

evaluate_regr(y_test, pred)
# Out:
# RMSE: 54.568, MAE: 38.372

# %%
pd.DataFrame(data=[pred, y_test])
# Out:
#          0          1           2           3           4          5     ...  \
# 0  219.228521  347.89639  279.434491  579.568721  360.124002  23.457644  ...
# 1  244.000000  239.00000  229.000000  467.000000  335.000000  40.000000  ...
#
#        2172       2173      2174        2175       2176        2177
# 0  5.509934  366.73173 -34.90171  702.745546  468.78553  107.113075
# 1  7.000000  340.00000   4.00000  627.000000  450.00000   75.000000
#
# [2 rows x 2178 columns]

# %%
from lightgbm import LGBMRegressor
lgbm_reg = LGBMRegressor(n_estimators=500)
lgbm_reg.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000675 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 352
# [LightGBM] [Info] Number of data points in the train set: 8708, number of used features: 72
# [LightGBM] [Info] Start training from score 190.855535

# %%
evaluate_regr(y_test, y_pred)
# Out:
# RMSE: 46.773, MAE: 30.562

# %%
pd.DataFrame(data=[y_pred, y_test])
# Out:
#          0           1           2          3           4         5     ...  \
# 0  243.948749  361.563298  282.707459  599.69412  354.766207  68.42725  ...
# 1  244.000000  239.000000  229.000000  467.00000  335.000000  40.00000  ...
#
#         2172       2173      2174        2175        2176       2177
# 0 -14.133085  374.31783  8.046399  759.344311  451.135498  75.163176
# 1   7.000000  340.00000  4.000000  627.000000  450.000000  75.000000
#
# [2 rows x 2178 columns]
